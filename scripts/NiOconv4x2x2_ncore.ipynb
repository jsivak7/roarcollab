# %% [markdown]
# # NiOconv4x2x2 NCORE
#
# $$Speedup = \frac{t(1)}{t(N)}$$
#
# where $t(1)$ is the computational time for running the software using one core, and $t(N)$ is the computational time running the same software with N cores. (https://hpc-wiki.info/hpc/Scaling)

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 200
plt.rcParams['figure.figsize'] = [5, 3]
plt.rcParams['font.size'] = 10
plt.rcParams['axes.linewidth'] = 1.25

# %%
bc_sr = pd.read_csv('../data/NiOconv4x2x2/ncore_singlenode/bc_sapphirerapids.csv')
sc_cl = pd.read_csv('../data/NiOconv4x2x2/ncore_singlenode/sc_cascadelake.csv')
sc_il = pd.read_csv('../data/NiOconv4x2x2/ncore_singlenode/sc_icelake.csv')

# %%
bc_sr
# Out:
#    num_cores     ncore1     ncore8    ncore16    ncore24    ncore32  \
# 0          1  37190.211  35579.859  35817.375  38306.367  28429.396
# 1          8   5467.561   4241.035   4629.841   4245.372   4249.384
# 2         16   3299.879   2590.860   2896.090   2825.010   2590.610
# 3         24   2642.845   1821.329   3137.467   1823.366   1843.436
# 4         32   4097.952   1916.786   2634.223   1776.620   2251.990
# 5         48   1353.950   1068.319   1038.792   1020.435   1273.990
# 6         64   2115.534   1100.888    917.903   1076.088    848.200
#
#      ncore48    ncore64
# 0  24892.025  25152.406
# 1   4243.359   4241.421
# 2   3683.952   2755.541
# 3   1713.853   1741.443
# 4   1374.387   1354.814
# 5   1188.611   1194.833
# 6   1090.791   1095.592

# %%
for ncore in [1, 8, 16, 24, 32, 48, 64]:
    plt.plot(bc_sr.num_cores, bc_sr[f"ncore1"][0]/bc_sr[f"ncore{ncore}"], label=ncore, marker='+', alpha=0.8)
plt.plot([0, 64], [0, 64], color='black', linestyle='--')
plt.xlabel("# cores")
plt.ylabel("speedup")
plt.title("Basic Cores (SapphireRapids)", weight='bold')
plt.legend(title='NCORE', loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig('../results/speedup_NiOconv4x2x2_ncore_bc_sapphirerapids.png')

# %%
for ncore in [1, 8, 16, 24, 32, 48]:
    plt.plot(sc_cl.num_cores, sc_cl[f"ncore1"][0]/sc_cl[f"ncore{ncore}"], label=ncore, marker='+', alpha=0.8)
plt.plot([0, 48], [0, 48], color='black', linestyle='--')
plt.xlabel("# cores")
plt.ylabel("speedup")
plt.title("Standard Cores (CascadeLake)", weight='bold')
plt.legend(title='NCORE', loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig('../results/speedup_NiOconv4x2x2_ncore_sc_cascadelake.png')

# %%
for ncore in [1, 8, 16, 24, 32, 48]:
    plt.plot(sc_il.num_cores, sc_il[f"ncore1"][0]/sc_il[f"ncore{ncore}"], label=ncore, marker='+', alpha=0.8)
plt.plot([0, 48], [0, 48], color='black', linestyle='--')
plt.xlabel("# cores")
plt.ylabel("speedup")
plt.title("Standard Cores (IceLake)", weight='bold')
plt.legend(title='NCORE', loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig('../results/speedup_NiOconv4x2x2_ncore_sc_icelake.png')
